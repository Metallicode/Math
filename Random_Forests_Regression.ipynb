# %% [markdown]
# <a href="https://colab.research.google.com/github/Metallicode/Math/blob/main/Random_Forests_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple Random Forests Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("rock_density_xray.csv")

# %%
df

# %%
X = df["Rebound Signal Strength nHz"]

# %%
y = df["Rock Density kg/m3"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
sns.scatterplot(data=df, x=X, y=y)
# Out:
# <Axes: xlabel='Rebound Signal Strength nHz', ylabel='Rock Density kg/m3'>

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=10)

# %%
regressor.fit(X_train.values.reshape(-1,1),y_train)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
preds = regressor.predict(np.arange(1,100).reshape(-1,1))

# %%
sns.scatterplot(data=df, x=X, y=y)
plt.plot(np.arange(1,100),preds, c="r")

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test,preds)
# Out:
# 0.34032713747541443

# %%
np.sqrt(mean_squared_error(y_test,preds))
# Out:
# 0.4288004668890397
